# %%
from datasets import load_dataset
import re
from nltk.corpus import wordnet
import nltk

# %%
nltk.download('wordnet')
esnli = load_dataset("../datasets/esnli.py")
esnli.data
# Out:
# [nltk_data] Downloading package wordnet to /Users/I518253/nltk_data...
# Found cached dataset esnli (/Users/I518253/.cache/huggingface/datasets/esnli/plain_text/0.0.2/64fd5bee4cf6dcae59e2b804162412bbe9646aab00da31dac1cecc0ad4f798fd)
#   0%|          | 0/3 [00:00<?, ?it/s]
# {'train': MemoryMappedTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  ----
#  premise: [["A person on a horse jumps over a broken down airplane.","A person on a horse jumps over a broken down airplane.","A person on a horse jumps over a broken down airplane.","Children smiling and waving at camera","Children smiling and waving at camera",...,"A child with a yellow cup and milk all over his face.","A child with a yellow cup and milk all over his face.","Two barefoot men are playing on a green lawn outside a building with other people in the background.","Two barefoot men are playing on a green lawn outside a building with other people in the background.","Two barefoot men are playing on a green lawn outside a building with other people in the background."],["Small laughing child with blond-hair sitting at a table holding a green sippy cup.","Small laughing child with blond-hair sitting at a table holding a green sippy cup.","Small laughing child with blond-hair sitting at a table holding a green sippy cup.","A little boy drinks milk and gets milk all over his face and table.","A little boy drinks milk and gets milk all over his face and table.",...,"A couple pose in front of a fountain.","A couple pose in front of a fountain.","A couple pose in front of a fountain.","Two women standing under an umbrella.","Two women standing under an umbrella."],...,["A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.","A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.","A woman wearing all orange clothing and a man wearing blue shorts are sweeping water into a drain in the ground next to a blue trashcan.","A woman wearing all orange clothing and a man wearing blue shorts are sweeping water into a drain in the ground next to a blue trashcan.","A woman wearing all orange clothing and a man wearing blue shorts are sweeping water into a drain in the ground next to a blue trashcan.",...,"BMX rider, riding downhill on forest path.","BMX rider, riding downhill on forest path.","BMX rider, riding downhill on forest path.","A young red-haired girl wants to see what comes after the clowns in the parade.","A young red-haired girl wants to see what comes after the clowns in the parade."],["A young red-haired girl wants to see what comes after the clowns in the parade.","Two men, one playing a purple guitar and the other playing an accordion, sitting on stone steps.","Two men, one playing a purple guitar and the other playing an accordion, sitting on stone steps.","Two men, one playing a purple guitar and the other playing an accordion, sitting on stone steps.","Two men, one playing a purple guitar and the other playing an accordion, sitting on stone steps.",...,"Four dirty and barefooted children.","Four dirty and barefooted children.","A man is surfing in a bodysuit in beautiful blue water.","A man is surfing in a bodysuit in beautiful blue water.","A man is surfing in a bodysuit in beautiful blue water."]]
#  hypothesis: [["A person is training his horse for a competition.","A person is at a diner, ordering an omelette.","A person is outdoors, on a horse.","They are smiling at their parents","There are children present",...,"The child has a clean face.","The child had milk all over his face.","Two men are barefoot on the lawn.","Two men in sandles are on the beach.","Two men are playing barefoot lawn darts."],["The child is happy.","A child is drinking apple juice.","A child is throwing a tantrum.","the kid has milk on his face on a school day","the dog eats mice",...,"There are two people in this picture","They are in Arizona on vacation","They are waiting to be picked up by aliens","two humans close together","a couple of friends share an umbrella on a rainy day"],...,["A woman is helping a man.","A woman working for the city is helping a coworker clean the streets.","A man and a woman cleaning up after a big thunder storm from the night before.","A man and a woman dancing in the rain.","A man and a woman outside.",...,"A bike rider in a pine forest.","A unicycle rider in the city.","A bike rider in the forest.","A girl is throwing up on the clowns at a parade.","A girl is scared of the clowns in the parade."],["A girl is watching a parade.","Two adults holding musical instruments.","Two men are playing music outside.","A band playing music for some pedestrians.","Two men are holding an outside concert.",...,"four kids won awards for 'cleanest feet'","four homeless children had their shoes stolen, so their feet are dirty.","A man in a bodysuit is competing in a surfing competition.","A man in a business suit is heading to a board meeting.","On the beautiful blue water there is a man in a bodysuit surfing."]]
#  label: [[1,2,0,1,0,...,2,0,0,2,1],[0,1,2,1,2,...,0,1,2,0,1],...,[0,1,1,2,0,...,1,2,0,2,1],[0,0,0,1,1,...,2,1,1,2,0]]
#  explanation_1: [["the person is not necessarily training his horse","One cannot be on a jumping horse cannot be a diner ordering food.","a broken down airplane is outdoors","Just because they are smiling and waving at a camera does not imply their parents or anyone is anyone behind it","The children must be present to see them smiling and waving.",...,"The child cannot have both a clean face and milk all over his face.","Child had milk all over his face it's another way of saying child with milk all over his face.","The men must be barefoot on the lawn interested to be barefoot men playing on a lawn.","The two men cannot be simultaneously barefoot and wearing sandles.","They are not shown to be playing lawn darts."],["Laughing is an expression of being happy.","A child holding a green sippy cup doesn't suggest the child is taking apple juice.","The small child can't be laughing and throwing a tantrum at the same time.","It may not be a school day.","The subject cannot be both a dog and a little boy.",...,"The two people in the picture are the couple posing.","Not every couple in front of a fountain is in Arizona.","The couple is posing for some purpose, not waiting on aliens.","Two women are under an umbrella, a small area of space so they are close together.","Not all women are friends."],...,["A woman is helping a man despite the extra detail that we are given.","sweep doesn't always mean the streets.","Sweeping water into a drain is not the same thing as cleaning up after a big thunder storm, and when this theoretical storm happened cannot be assumed.","A man and a woman cannot be dancing in the rain while sweeping water into a drain in the ground","A man and a woman are outside because drains are in the ground outside.",...,"The rider may not be in a pine forest. The rider could be in a forest (albeit not a pine one) or he/she could be on a path that resembles a forest because of a high number of trees.","There can either be a BMX rider or a unicycle rider.","BMX rider on forest path is just as bike rider in the forest","Comes and throwing are different.","Wants to see what comes does not imply being scared."],["If a girl wants to see what comes next, it follows that she is watching.","Adults are men and a guitar and accordion are musical instruments.","The men are playing guitar and an accordion so they are playing music.","Two men, one playing a purple guitar and the other playing an accordion, sitting on stone steps does not indicate that a band playing music for some pedestrians.","Just because two men are playing instruments, doesn't mean they're holding a concert.",...,"in a both sentence dirty and cleanest are not same.","the children are not necessarily homeless","the man is not necessarily competing","That is either a business suit or bodysuit.","The man is in a bodysuit and he is surfing on the water."]]
#  explanation_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  explanation_3: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  premise_highlighted_1: [["{}","4,2,3,5","8,9,10,7","{}","0,1,3,2",...,"7,9,8,10,11","2,7,8,9,11,1,10","1,2,4,5,6,8","1","{}"],["1","{}","1","{}","1,2",...,"1","{}","2","0,1","{}"],...,["1,13,15","{}","{}","20,17,13,14,15,19,18,16","1,8,17,20",...,"{}","0,1","0,1,4,5,6","8","{}"],["4,5,6","1,6,12","3,6,10,12","{}","{}",...,"1","{}","{}","6","3,6,10,7,1,2,4"]]
#  hypothesis_highlighted_1: [["3,4,5","2,5,4,3,6","3","5,3,4","3",...,"4,5","2,1,5,3,4,6,7","1,2,3,4,5,6","3","5,6"],["3","4","3,4,5","9,10","1",...,"2","3","2","0,1","3"],...,["1,3,5","11,12","11,10,9,5,6,7,8,14,15","5,8,7,6","{}",...,"5,6","1","1,2,3,4,5","3","3"],["2,3","1,4,3","4,3","5,6","3,6",...,"5","1","6","4,5","11,12,0,4"]]
#  premise_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  ...,
#  'validation': MemoryMappedTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  ----
#  premise: [["Two women are embracing while holding to go packages.","Two women are embracing while holding to go packages.","Two women are embracing while holding to go packages.","Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.","Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.",...,"A woman stands at a podium with a slide show behind her.","A surfer is surfing catches a wave.","A surfer is surfing catches a wave.","A surfer is surfing catches a wave.","Two people are looking at something in New York City."],["Two people are looking at something in New York City.","Two people are looking at something in New York City.","A man sleeping on the ground in a subway.","A man sleeping on the ground in a subway.","A man sleeping on the ground in a subway.",...,"two young children on a skateboard going across a sidewalk","Two fencers dressed in the sport's traditional white suit and protective mask, practice their dueling.","Two fencers d
#  explanation_3: [["Two women do not have to be sisters.  Embracing does not mean hugging goodbye.  The women do not have to have just finished lunch to be embracing.","Women can embrace while they are holding packages.","First sentence features two women and the second has men.","Kids is a synonym for children.","Just because two children are in jerseys washing their hands in a sink it does not mean they are at a ballgame.",...,"A woman is not a girl.","If one catches a wave, there is no way that he walks to the hot dog truck at the same time.","A surfer catches a wave while surfing.","The wave is just a wave according to sentence one. A tsunami sized wave is not implied.","Woman looking outside is not a complete sentence. Also the first sentence does not imply gender of the two people nor does it imply they have to be looking outside."],["Looking at New York is too specific according to the information given in sentence 1. They are looking at something, but not necessarily New York.","The two people are looking at something, but how they feel about it is not implied in sentence 1. We do not know that they are enjoying themselves.","One usually does not sleep sitting down and his warm house is not a subway station.","The man is on the ground because he's sleeping.","The first sentence does not indicate the man has a dog. You can sleep without having your dog next to you or having a dog at all.",...,"We don't know where the children are going on the skateboard, nothing implies that they are going tot he park.","Two women cannot simultaneously play water polo and practice their dueling for fencing.","Pair is descriptive of two.","Fencers practicing dueling doesn't suggest that they slash violently at each other.","Running implies moving at a fast speed."],...,["A tattooed boxer cannot be without tattooes. Some outdoors cannot be in a boxing arena at the same time. A person punching his opponent cannot be described as getting beat up.","A boxer punching his opponent is competing in a fight.","A young man can stare without staring at a young woman.","If you're asleep that implies your eyes are closed, you cannot be staring.","A young man has to have his eyes open in order to stare at anything.",...,"If they are going home, then the boy would not be in the water.","The boy is with his mum","A child from playing toy games usually doesn't go home crying.","The father is either cuddling the children or drowns them.","Three people can be a father and his two children."],["Cuddling with his children doesn't mean he reads to them.","Two is more than one.","Holding his babies doesn't always mean posing for a picture.","A man that is childless cannot be holding his two adorable babies.","Holding fans doesn't necessarily mean she's fanning herself.",...,"If the girl is riding the carousel then it must be moving.","Carousels do not move at the speed of light.","A girl and woman are people in a water fountain.","A young girl in a fountain would not be standing as she knits.","Just because a woman is with a girl does not mean she is her mother. Just because she grabs the child does not mean it is before she attracts attention."]]
#  premise_highlighted_1: [["{}","6,7,8","1,3","2,1,10,9,15,16,5","{}",...,"1","3","1,4,6","{}","{}"],["{}","{}","3,4,5,8,2","2,3,4,5","{}",...,"{}","1","12,13,14,0","{}","0,1,2,4,5,6"],...,["9,10","4,5,6","{}","4","5,7,6",...,"6,7","2,3,5","{}","9","13,12,1"],["{}","1,4,5,6","{}","6","{}",...,"8,11","8,9,10,11","1,0,2,15,16","25,16","{}"]]
#  hypothesis_highlighted_1: [["13","3,4","1,3","1,3,4","2,3,4",...,"1","2,3,4,5,6,7","1,2,4","5","1"],["2,3,4,5","4,3","4,5,7,3","3,4,5,6","7",...,"4,5,6,7","4,3","4,5,1","2","0,2,3"],...,["8","3,4,6,5","8,9","4","5",...,"6,5","1,3,5","7","2","2"],["2,6,7,8,9,10","6","7,8,9,10","3","8,9,10,11,12",...,"3","6,7,8","0","3","2,13,14,15,16,3,4,5"]]
#  premise_highlighted_2: [["{}","0,1,5,8","0,1,3","2,26,1,0,31","{}",...,"1","3","3","{}","{}"],["{}","{}","2,8","1,2,5","{}",...,"{}","1,12,13,14","0,1,14,13,12","{}","0,1,2"],...,["1","4,6","{}","4,5,6,7","5",...,"6,7,8,9","1,2","{}","9","1,12,13"],["{}","4,6","{}","4,6","{}",...,"2,8","8,9,11,10","2,16","25","{}"]]
#  hypothesis_highlighted_2: [["1,3,4","{}","1,3","4,7","4",...,"1","2","1","5,6","3,2"],["4,5,2","3,4","3,7","6","4,5,6,7",...,"4,5,6,7","1,2,3,4","1,3,5,4","2,3,4,5,6","0,2,3"],...,["2,3","3,6","9","4","5,6",...,"6,7,8,9","1","7","2","2,3"],["2","3,4,5,6","6,7,8,9,10","3","9",...,"1","4,5,6,7,8","0","3","2,15,16"]]
#  ...,
#  'test': MemoryMappedTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  ----
#  premise: [["This church choir sings to the masses as they sing joyous songs from the book at a church.","This church choir sings to the masses as they sing joyous songs from the book at a church.","This church choir sings to the masses as they sing joyous songs from the book at a church.","A woman with a green headscarf, blue shirt and a very big grin.","A woman with a green headscarf, blue shirt and a very big grin.",...,"Three children hold a boy's arms down while another boy in a hat shoots a water gun at him.","A dog runs.","A dog runs.","A dog runs.","A brown and black dog runs on the grass outdoors in front of a sidewalk."],["A brown and black dog runs on the grass outdoors in front of a sidewalk.","A brown and black dog runs on the grass outdoors in front of a sidewalk.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.",...,"A group of people sitting and knitting.","A young Asian girl is wearing a pink dress and holding an umbrella even though it is not raining.","A young Asian girl is wearing a pink dress and holding an umbrella even though it is not raining.","A young Asian girl is wearing a pink dress and holding an umbrella even though it is not raining.","A young woman wearing a yellow sweater and black pants is ice skating outdoors."],...,["A smiling girl walking and a frowning girl with a phone.","A smiling girl walking and a frowning girl with a phone.","A smiling girl walking and a frowning girl with a phone.","A short-haired man is jumping while on top of a huge boulder.","A short-haired man is jumping while on top of a huge boulder.",...,"A man in a red shirt is walking towards a blue market stall.","Indy car, white, blue with a red mark on the roof, rounding a turn, in front of the white car.","Indy car, white, blue with a red mark on the roof, rounding a turn, in front of the white car.","Indy car, white, blue with a red mark on the roof, rounding a turn, in front of the white car.","A young boy sits on the shoulders of a woman, who is carrying a young girl."],["A young boy sits on the shoulders of a woman, who is carrying a young girl.","A young boy sits on the shoulders of a woman, who is carrying a young girl.","A young blond child wearing a black shirt and white shorts looks at the sky with a bridge and water in the background.","A young blond child wearing a black shirt and white shorts looks at the sky with a bridge and water in the background.","A young blond child wearing a black shirt and white shorts looks at the sky with a bridge and water in the background.",...,"Two women are observing something together.","Two women are observing something together.","A man in a black leather jacket and a book in his hand speaks in a classroom.","A man in a black leather jacket and a book in his hand speaks in a classroom.","A man in a black leather jacket and a book in his hand speaks in a classroom."]]
#  hypothesis: [["The church has cracks in the ceiling.","The church is filled with song.","A choir singing at a baseball game.","The woman is young.","The woman is very happy.",...,"There are five children.","The dog is running outside","The dog runs","The dog is walking","The big dog is playing with a toy."],["The animal is sleeping in the basement.","A canine is using his legs.","A family skeet shooting","A black family selling fresh produce in an outdoor market","People at an outdoor market",...,"A group of women are knitting.","The girl in a pink dress uses an umbrella for a sun shade.","The girl in pink holding an umbrella.","The girl in a blue dress is standing in the rain with an umbrella.","a woman is active"],...,["A smiling boy walking and a frowning girl with a phone.","A smiling girl walking and a frowning girl with a cellphone.","A  girl walking and a frowning girl with a phone.","The man is jumping to another boulder.","The man is sitting down on the rock.",...,"The man is sitting on a bench.","Race cars","People playing racketball","A driver passing his opponent on the last lap","A family is at the mall"],["A woman is driving her kids around","A woman is with a couple of children","A child looks at birds in the sky outside of of a bridge.","A child takes a nap on a couch.","A child looks at the sky outside.",...,"Two women are standing with their eyes closed.","Two girls are looking at something.","A man is flying a kite.","A man is speaking in a classroom.","A man is teaching science in a classroom."]]
#  label: [[1,0,2,1,0,...,0,1,0,2,1],[2,0,2,1,0,...,1,1,0,2,0],...,[2,0,0,1,2,...,2,0,2,1,1],[2,0,1,2,0,...,2,0,2,0,1]]
#  explanation_1: [["Not all churches have cracks in the ceiling",""Filled with song" is a rephrasing of the "choir sings to the masses."","A choir sing some other songs other than book at church during the base play. they cannot see book and play base ball same time.","the woman could've been old rather than young","a grin suggests hapiness.",...,"Three children plus a boy, plus another boy equal five children.","we know the dog can run, but we don't know it is running.  Also, we don't know where the dog runs, so it may not be outside.","A dog is the dog.","A dog cannot run if the dog is walking.","Not all dogs are big."],["An animal who runs is not sleeping.","A canine is a dog and a dog that runs is definitely using his Legs.","The family is in a market not skeet shooting.","Being at a market doesn't mean you're selling something, you could be a buyer.","A mother and her two little boys are collectively called as people.  Both people are on an outdoor market.",...,"Sentence one says "people." It doesn't say they're all women.","The girl could hold the umbrella for many reasons.  Not everyone holds an umbrella for sun shade.","A girl in pink is wearing a pink dress.","A girl can not be standing in the rain with an umbrella and be holding an umbrella when it is not raining.","A woman that is ice skating is active."],...,["A girl is not the same as a boy.","A cellphone is a type of phone.","In both sentences, one of the actors is a frowning girl with a phone.","A man jumping on a boulder is not assumed to be jumping to another boulder.","One cannot jump while sitting down.",...,"One cannot be sitting and walking at the same time.","
holding an umbrella doesn't imply using it as sun shade.","The girl can be a young Asian girl. A dress can be pink.","The girl can either be wearing a pink dress or blue dress. It can either be raining or not raining.","The young woman ice skating outdoors is the woman being active"],...,["It is either a smiling boy or girl.","A cellphone is also called a phone.","there is a frowning girl with a phone, and a second girl who is walking","Jumping while on top of huge boulder does not mean jumping to another boulder.","You cannot be sitting and jumping at the same time.",...,"It is impossible to be both sitting and walking simultaneously.","Indy cars are race cars.","People do not use racket ball while driving indy cars,","The driver may or may not be on the last lap and no indication he has passed, maybe has been in front the whole time.","No reference to the mall, and the collection of people doesn't have to be a family."],["If a woman is driving she cannot carry children at the same time","A boy and a girl which means a couple of children are being carried by the women","No indication that there are birds in the sky.","One cannot look at the sky whilst taking a nap on a couch.","Young blond child explains the type of child. A bridge and water are found outside.",...,"Observing implies that you are watching or looking at something, if your eyes are closed you cannot be observing.","Women are starring at something.","a man would either speaks in classroom or flying a kite","A MAN CAN WEAR A BLACK JACKET AND SPEAK IN A CLASSROOM","The man may not be teaching, and if he is, it might be something other than science."]]
#  premise_highlighted_1: [["{}","2,3,4,5,6","6,14,17","{}","12",...,"0,1,3,4,5,8,9","{}","1,0","1,2","{}"],["5","4,5","16,17","{}","2,10,9,11,17,16",...,"{}","{}","5,6,7,8","10,12,17,18","11,12"],...,["2","10","6,7,10","{}","3,4",...,"7","0,1","11,12,13","{}","{}"],["12,3,6","1,2,14,15","{}","14","17,18,19,20,21,22",...,"3","3","13,14,15,16","13","{}"]]
#  hypothesis_highlighted_1: [["3,6,4,5","3,4,5","2,5,6","3","4",...,"2,3","4,3","1,0","1,3","1,2"],["3","1,5","2,3","3","3,4",...,"3","11,12","2,3","7,8,9,10,11,12,13","3"],...,["2","10","6,7,10","4,5,6","3,4,2",...,"3","0,1","1,2","4","3,4,5,1"],["3","4,7,5,6","4,8","4","6",...,"6,7","3","3,4,5","3","4"]]
#  premise_highlighted_2: [["{}","10","17","{}","0,1,10,11,12",...,"15,16,13","{}","0,1","2","{}"],["4,9,5","4,5","17,18","{}","2,10,11,13",...,"{}","{}","1,2,3,5,6,7,8","7,8","12,11"],...,["2","10","2,3,6,7,10","{}","3,4",...,"7,12,11","1,0,19","11,18,19","{}","{}"],["12,15,2","1,2,14,15","{}","12,13,14,11","16,17,18,19,20,21,22",...,"3","3,4","14,15,16","16,1,13","{}"]]
#  hypothesis_highlighted_2: [["3,4,5,6","5","5,6","3","4",...,"3","4","0,1","2,3","7"],["1,3,6,5,4","1,3,4,5","2,3","3,4,5","0",...,"3,5","12,11,8","1,2,3","4,5","3"],...,["2","10","2,10,9,6,7","5,6","3,4",...,"3,6","0,1","1,0","4,2","1,5"],["1,5,4","5,6,7","4","2,3,4","6",...,"7,6","3,5","5,3,4","6,1,3","3,4,1,2,5,7"]]
#  ...}

# %%
def transform_highlighted(record: dict) -> dict:
    highlighted_premise_all = set()
    highlighted_hypothesis_all = set()
    for i in range(1, 4):
        highlighted_current_premise = get_words_at_indices(record["premise"], parse_indices(record[f"premise_highlighted_{i}"]))
        highlighted_premise_all.update(highlighted_current_premise)
        record[f"premise_highlighted_{i}"] = ",".join(highlighted_current_premise)
        highlighted_current_hypothesis = get_words_at_indices(record["hypothesis"], parse_indices(record[f"hypothesis_highlighted_{i}"]))
        highlighted_hypothesis_all.update(highlighted_current_hypothesis)
        record[f"hypothesis_highlighted_{i}"] = ",".join(highlighted_current_hypothesis)
    record["highlighted_premise_all"] = ",".join(highlighted_premise_all)
    record["highlighted_hypothesis_all"] = ",".join(highlighted_hypothesis_all)
    return record

def parse_indices(indices: str) -> list[int]:
    if indices in [r"{}", ""]:
        return []
    return [int(i) for i in indices.split(",")]

def get_words_at_indices(string: str, indices: list[int]) -> str:
    split_string = string.split(" ")
    return filter(lambda word: word != "", map(lambda i: re.sub(r"[.,!?]", "", split_string[i]), indices))

splits = ["train", "test", "validation"]
for split in splits:
    esnli[split] = esnli[split].map(transform_highlighted, num_proc=8)

esnli.data
# Out:
# Loading cached processed dataset at /Users/I518253/.cache/huggingface/datasets/esnli/plain_text/0.0.2/64fd5bee4cf6dcae59e2b804162412bbe9646aab00da31dac1cecc0ad4f798fd/cache-91045558473ae8b9_*_of_00008.arrow
# Loading cached processed dataset at /Users/I518253/.cache/huggingface/datasets/esnli/plain_text/0.0.2/64fd5bee4cf6dcae59e2b804162412bbe9646aab00da31dac1cecc0ad4f798fd/cache-63693622c32f55df_*_of_00008.arrow
# Loading cached processed dataset at /Users/I518253/.cache/huggingface/datasets/esnli/plain_text/0.0.2/64fd5bee4cf6dcae59e2b804162412bbe9646aab00da31dac1cecc0ad4f798fd/cache-1da715ce42a35d5b_*_of_00008.arrow
# {'train': ConcatenationTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  highlighted_premise_all: string
#  highlighted_hypothesis_all: string
#  ----
#  premise: [["A person on a horse jumps over a broken down airplane.","A person on a horse jumps over a broken down airplane.","A person on a horse jumps over a broken down airplane.","Children smiling and waving at camera","Children smiling and waving at camera",...,"A child with a yellow cup and milk all over his face.","A child with a yellow cup and milk all over his face.","Two barefoot men are playing on a green lawn outside a building with other people in the background.","Two barefoot men are playing on a green lawn outside a building with other people in the background.","Two barefoot men are playing on a green lawn outside a building with other people in the background."],["Small laughing child with blond-hair sitting at a table holding a green sippy cup.","Small laughing child with blond-hair sitting at a table holding a green sippy cup.","Small laughing child with blond-hair sitting at a table holding a green sippy cup.","A little boy drinks milk and gets milk all over his face and table.","A little boy drinks milk and gets milk all over his face and table.",...,"A couple pose in front of a fountain.","A couple pose in front of a fountain
ple posing.","Not every couple in front of a fountain is in Arizona.","The couple is posing for some purpose, not waiting on aliens.","Two women are under an umbrella, a small area of space so they are close together.","Not all women are friends."],...,["Just because one dog is biting the other doesn't make it a female dog.","either it is one dog or two","A woman with her hand outstretched can reasonable be described as reaching for something, since reaching involves outstretching a hand.","Just because the woman has her hand outstretched doesn't mean she is preparing to shake hands with someone.","A boy is male and women are female and you cannot be both.",...,"If another man films it then a man is filming.","the woman is not necessarily near a shop","woman wearing a red bow walks past a bicycle simply means woman with a bow walking near a bike","Wearing isn't riding.","beach on an overcast day is just as there is an overcast at the beach."],["the people is not necessarily there for a tournament","Overcast isn't sunny.","Riding and rides are the same words but in a different verb tense.","A man can ride a horse that is not his favorite.","You can either ride a horse or a bull.",...,"in a both sentence dirty and cleanest are not same.","the children are not necessarily homeless","the man is not necessarily competing","That is either a business suit or bodysuit.","The man is in a bodysuit and he is surfing on the water."]]
#  explanation_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  explanation_3: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  premise_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  premise_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  ...,
#  'validation': ConcatenationTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  highlighted_premise_all: string
#  highlighted_hypothesis_all: string
#  ----
#  premise: [["Two women are embracing while holding to go packages.","Two women are embracing while holding to go packages.","Two women are embracing while holding to go packages.","Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.","Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.",...,"A woman stands at a podium with a slide show behind her.","A surfer is surfing catches a wave.","A surfer is surfing catches a wave.","A surfer is surfing catches a wave.","Two people are looking at something in New York City."],["Two people are looking at something in New York City.","Two people are looking at something in New York City.","A man sleeping on the ground in a subway.","A man sleeping on
#  premise_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  premise_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  ...,
#  'test': ConcatenationTable
#  premise: string
#  hypothesis: string
#  label: int64
#  explanation_1: string
#  explanation_2: string
#  explanation_3: string
#  premise_highlighted_1: string
#  hypothesis_highlighted_1: string
#  premise_highlighted_2: string
#  hypothesis_highlighted_2: string
#  premise_highlighted_3: string
#  hypothesis_highlighted_3: string
#  premise_marked_1: string
#  hypothesis_marked_1: string
#  premise_marked_2: string
#  hypothesis_marked_2: string
#  premise_marked_3: string
#  hypothesis_marked_3: string
#  highlighted_premise_all: string
#  highlighted_hypothesis_all: string
#  ----
#  premise: [["This church choir sings to the masses as they sing joyous songs from the book at a church.","This church choir sings to the masses as they sing joyous songs from the book at a church.","This church choir sings to the masses as they sing joyous songs from the book at a church.","A woman with a green headscarf, blue shirt and a very big grin.","A woman with a green headscarf, blue shirt and a very big grin.",...,"Three children hold a boy's arms down while another boy in a hat shoots a water gun at him.","A dog runs.","A dog runs.","A dog runs.","A brown and black dog runs on the grass outdoors in front of a sidewalk."],["A brown and black dog runs on the grass outdoors in front of a sidewalk.","A brown and black dog runs on the grass outdoors in front of a sidewalk.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.","A black mother in an orange dress with her two little boys and husband at an outdoor market stand.",...,"San Fransisco 49ers football field with cheerleaders and a packed stadium.","San Fransisco 49ers football field with cheerleaders and a packed stadium.","A man in an army uniform meeting someone foreign.","A man in an army uniform meeting someone foreign.","A man in an army uniform meeting someone foreign."],...,["A blond woman with a tattoo of on an angel on her arm walking down the street, a concrete wall in the background.","A blond woman with a tattoo of on an angel on her arm walking down the street, a concrete wall in the background.","A blond woman with a tattoo of on an angel on her arm walking down the street, a concrete wall in the background.","A woman looks at a picture and framing tools while standing in a sparse building with wooden floors and bare white walls.","A woman looks at a picture and framing tools while standing in a sparse building with wooden floors and bare white walls.",...,"A man squatting in a park looking at something in the distance.","A man squatting in a park looking at something in the distance.","A man squatting in a park looking at something in the distance.","A snowboarder with a maroon coat sails through the air.","A snowboarder with a maroon coat sails through the air."],["A snowboarder with a maroon coat sails through the air.","A man is in front of a dryer in a laundromat with both hands reaching into a bin or basket.","A man is in front of a dryer in a laundromat with both hands reaching into a bin or basket.","A man is in front of a dryer in a laundromat with both hands reaching into a bin or basket.","there's a woman in a pink and gray striped outfit standing with five children, three of which are making faces.",...,"Two women are observing something together.","Two women are observing something together.","A man in a black leather jacket and a book in his hand speaks in a classroom.","A man in a black leather jacket and a book in his hand speaks in a classroom.","A man in a black leather jacket and a book in his hand speaks in a classroom."]]
#  hypothesis: [["The church has cracks in the ceiling.","The church is filled with song.","A choir singing at a baseball game.","The woman is young.","The woman is very happy.",...,"There are five children.","The dog is running outside","The dog runs","The dog is walking","The big dog is playing with a toy."],["The animal is sleeping in the basement.","A canine is using his legs.","A family skeet shooting","A black family selling fresh produce in an outdoor market","People at an outdoor market",...,"The 49ers are ready to play versus their rivals.","The football game got cancelled and the field is empty.","A man in an army uniform is meeting someone.","A man in an army uniform is meeting a foreign civilian in the war zone.","A man in a navy uniform is meeting his wife."],...,["Nobody has a tattoo","A person with a tattoo","A person with a great tatto","A woman is dancing in an art gallery.","There is a person in a room.",...,"A man is watching his son playing on the swingset.","A man is swimming in the ocean.","A man sees something while in a park.","The snowboarder has never tried this jump before.","A person is snowboarding."],["The snowboarder is naked.","A woman reaches into a basket at a store","A man reaches into his laundry basket at the laundromat","A man reaches into a basket at a laundromat","the woman is standing",...,"Two women are standing with their eyes closed.","Two girls are looking at something.","A man is flying a kite.","A man is speaking in a classroom.","A man is teaching science in a classroom."]]
#  label: [[1,0,2,1,0,...,0,1,0,2,1],[2,0,2,1,0,...,1,2,0,1,2],...,[2,0,1,2,0,...,1,2,0,1,0],[2,2,0,0,0,...,2,0,2,0,1]]
#  explanation_1: [["Not all churches have cracks in the ceiling",""Filled with song" is a rephrasing of the "choir sings to the masses."","A choir sing some other songs other than book at church during the base play. they cannot see book and play base ball same time.","the woman could've been old rather than young","a grin suggests hapiness.",...,"Three children plus a boy, plus another boy equal five children.","we know the dog can run, but we don't know it is running.  Also, we don't know where the dog runs, so it may not be outside.","A dog is the dog.","A dog cannot run if the dog is walking.","Not all dogs are big."],["An animal who runs is not sleeping.","A canine is a dog and a dog that runs is definitely using his Legs.","The family is in a market not skeet shooting.","Being at a market doesn't mean you're selling something, you could be a buyer.","A mother and her two little boys are collectively called as people.  Both people are on an outdoor market.",...,"They may not be rivals with the other team.","The stadium can't be packed if it's empty.","A man is meeting someone foreign.","If a man in uniform is meeting someone foreign, it does not mean the foreigner is a civilian, or that they are in a war zone.","A man cannot be in the army and navy. His wife would not be someone foreign."],...,["Either nobody has a tattoo or there is a blond woman with a tattoo, but not both simultaneously.","Person can be used as a synonym for woman, as women are people.","A tattoo may not be great looking.","Dancing is a different action than standing.","A woman is a person and wooden floors with bare walls describes the room",...,"looking at something doesn't mean son playing","One cannot be squatting and swimming simultaneously.","Man squatting is a type of man, and sees is a synonym of looking.","Nothing says if this snowboarder has never tried this jump before.","A snowboarder is a person, and when a snowboarder "sails through the air" they are snowboarding, therefore a person is snowboarding."],["One cannot wear a coat and be naked.","A person cannot be both a man and a woman.","A  in a laundromat with both hands reaching into a bin or basket indicates that he is reaching a laundry basket at the laundromat.","Dryer implies laundromat.","The woman is standing with children.",...,"Answer: The women cannot be observing with eyes closed","Observing is a synonym for looking.","A man who speaks in a classroom can not be flying a kite.","speaks is the same as speaking","doesn't mean it's a science class"]]
. A sparse building with bare white walls is unlikely to be an art gallery.","Person is a more generalized term to describe a woman. She is a person.",...,"A man squatting in a park looking at something in the distance doesn't mean that man is watching his son playing on the swingset.","A person cannot be squatting and swimming at the same time. A person cannot be in a park and in the ocean at the same moment.","Looking at something is a rephrasing of sees something.","A snowboarder with a maroon coat sailing through the air doesn't mean that the snowboarder has never tried this jump before.","Sails is done by a person"],["The snowboarder cannot be both naked and wearing a coat.","The person changes from man to woman.","A man reaches the laundry basket at the laundromat to took off his clothes from that.","At the laundromat a man reaches into a basket","the woman standing with five children means the woman is standing",...,"Observing implies that you are watching or looking at something, if your eyes are closed you cannot be observing.","Women are starring at something.","a man would either speaks in classroom or flying a kite","A MAN CAN WEAR A BLACK JACKET AND SPEAK IN A CLASSROOM","The man may not be teaching, and if he is, it might be something other than science."]]
#  premise_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  premise_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  hypothesis_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
#  ...}

# %%
def get_antonyms(word: str) -> set[str]:
    antonyms = []
    for synset in wordnet.synsets(word):
        for lemma in synset.lemmas():
            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())
    return set(antonyms)

def important_words_contain_antonym(record):
    important_premise = set(record["highlighted_premise_all"].split(","))
    important_hypothesis = set(record["highlighted_hypothesis_all"].split(","))
    for word_premise in important_premise:
        antonyms = get_antonyms(word_premise)
        if len(antonyms.intersection(important_hypothesis)) > 0:
            return True
    return False

esnli_test_antonyms = esnli["test"].filter(important_words_contain_antonym, num_proc=8)
# Out:
# Filter (num_proc=8):   0%|          | 0/9824 [00:00<?, ? examples/s]
# ConcatenationTable
# premise: string
# hypothesis: string
# label: int64
# explanation_1: string
# explanation_2: string
# explanation_3: string
# premise_highlighted_1: string
# hypothesis_highlighted_1: string
# premise_highlighted_2: string
# hypothesis_highlighted_2: string
# premise_highlighted_3: string
# hypothesis_highlighted_3: string
# premise_marked_1: string
# hypothesis_marked_1: string
# premise_marked_2: string
# hypothesis_marked_2: string
# premise_marked_3: string
# hypothesis_marked_3: string
# highlighted_premise_all: string
# highlighted_hypothesis_all: string
# ----
# explanation_1: [["Not all churches have cracks in the ceiling",""Filled with song" is a rephrasing of the "choir sings to the masses."","A choir sing some other songs other than book at church during the base play. they cannot see book and play base ball same time.","the woman could've been old rather than young","a grin suggests hapiness.",...,"Three children plus a boy, plus another boy equal five children.","we know the dog can run, but we don't know it is running.  Also, we don't know where the dog runs, so it may not be outside.","A dog is the dog.","A dog cannot run if the dog is walking.","Not all dogs are big."],["An animal who runs is not sleeping.","A canine is a dog and a dog that runs is definitely using his Legs.","The family is in a market not skeet shooting.","Being at a market doesn't mean you're selling something, you could be a buyer.","A mother and her two little boys are collectively called as people.  Both people are on an outdoor market.",...,"They may not be rivals with the other team.","The stadium can't be packed if it's empty.","A man is meeting someone foreign.","If a man in uniform is meeting someone foreign, it does not mean the foreigner is a civilian, or that they are in a war zone.","A man cannot be in the army and navy. His wife would not be someone foreign."],...,["Either nobody has a tattoo or there is a blond woman with a tattoo, but not both simultaneously.","Person can be used as a synonym for woman, as women are people.","A tattoo may not be great looking.","Dancing is a different action than standing.","A woman is a person and wooden floors with bare walls describes the room",...,"looking at something doesn't mean son playing","One cannot be squatting and swimming simultaneously.","Man squatting is a type of man, and sees is a synonym of looking.","Nothing says if this snowboarder has never tried this jump before.","A snowboarder is a person, and when a snowboarder "sails through the air" they are snowboarding, therefore a person is snowboarding."],["One cannot wear a coat and be naked.","A person cannot be both a man and a woman.","A  in a laundromat with both hands reaching into a bin or basket indicates that he is reaching a laundry basket at the laundromat.","Dryer implies laundromat.","The woman is standing with children.",...,"Answer: The women cannot be observing with eyes closed","Observing is a synonym for looking.","A man who speaks in a classroom can not be flying a kite.","speaks is the same as speaking","doesn't mean it's a science class"]]
# explanation_2: [["There is no indication that there are cracks in the ceiling of the church.","hearing song brings joyous in the church.","The choir is at a chruch not a baseball game.","There is no indication that the woman is young.","A WOMAN WITH BIG GRIN IS HAPPY",...,"Children are playing a water gun by shoots each other.","Dogs run inside and outside.","A dog is the dog.","It is not possible for a dog to be running and walking at the same time.","Dogs can run without playing with a toy."],["An animal does not have to be a dog.  If a dog runs outdoors then it is not sleeping in the basement.","canine refers to dog. runs is rephrased as using his legs.","The family is either at a market stand or is skeet shooting.","A black family may be at a market for other reasons than selling fresh produce.","Answer: People here include a mother, little boys and husband.",...,"They may not be getting ready to play versus the rivals","The stadium would not be packed or have cheerleaders if it was empty.","The man in an army uniform is meeting someone.","It cannot be assumed the foreign one is civilian and it is a war zone.","Army uniform and navy uniform cannot be worn at the same time."],...,["The woman either has a tattoo or nobody has a tattoo.","A blond woman is a person with a tattoo.","having a tattoo doesn't imply it's a great tattoo.","Standing and dancing are two different activities","Woman is person, and white walls implies room.",...,"Just because the man is looking at something in the distance doesn't mean that he is watching his son.","A man cannot be swimming and squatting at the same time.","Sees something is a paraphrase of looking at something.","Just because the snowboarder jumps doesn't mean he never tried the jump before.","A PERSON IS SNOWBOARDING THROUGH THE AIR"],["The snowboarder can't wear a coat while naked.","A laundromat is not inside a store.","If the man at the laundromat is reaching into a bin or basket, it can be assume the basket is his.","it is a rephrasing of the same event with less descriptive info man, reaches, basket laundromat","Woman in a pink and gray striped outfit is a type of woman.",...,"Observing means their eyes are not closed.","If the girls are observing something, they are looking at something.","A man cannot fly a kite and speak in a classroom simultaneously.","Speaking and speaks are different tenses of the verb to speak, and they are both happening in a classroom.","Just because a man speaks with a book in his hand in a classroom it does not mean he is teaching science."]]
# explanation_3: [["Not all churches have cracks in the ceiling.","If the church choir sings then the church is filled with song.","A baseball game isn’t played at a church.","Not all women are young.","One must be happy in order to have a big grin.",...,"Five children are playing with a water gun.","A dog that is running may not be running outside.","According to sentence two, the dog runs.","A dog cannot run and be walking at the same time.","The brown and black dog may not have been big. Also he could be outdoors but may not be playing with a toy."],["The animal cannot be both running outdoors and sleeping in the basement.","A dog is a canine and if he runs he is using his legs.","a family would either be in outdoor market stand or skeet shooting","The black mother could be at the outdoor market shopping and not necessarily selling fresh produce.","Mother, boys and husband are people.",...,"Although the stadium is packed, it does not mean they are ready to play versus their rivals.","field can't be empty and have cheerleaders and a packed stadium","Someone that is foreign is someone and the man is meeting them.","Meeting someone foreign doesn't mean they are a civilian or that the meeting is in a war zone.","One man can't be in the army and navy at the same time, plus his wife wouldn't be considered foreign."],...,["If nobody has a tattoo there can’t be a woman with a tattoo.","A person with a tattoo is repeated and is a subset of a more comprehensive description of a woman with a tattoo.","Not all tattoos are great.","A standing woman cannot be dancing. A sparse building with bare white walls is unlikely to be an art gallery.","Person is a more generalized term to describe a woman. She is a person.",...,"A man squatting in a park looking at something in the distance doesn't mean that man is watching his son playing on the swingset.","A person cannot be squatting and swimming at the same time. A person cannot be in a park and in the ocean at the same moment.","Looking at something is a rephrasing of sees something.","A snowboarder with a maroon coat sailing through the air doesn't mean that the snowboarder has never tried this jump before.","Sails is done by a person"],["The snowboarder cannot be both naked and wearing a coat.","The person changes from man to woman.","A man reaches the laundry basket at the laundromat to took off his clothes from that.","At the laundromat a man reaches into a basket","the woman standing with five children means the woman is standing",...,"Observing implies that you are watching or looking at something, if your eyes are closed you cannot be observing.","Women are starring at something.","a man would either speaks in classroom or flying a kite","A MAN CAN WEAR A BLACK JACKET AND SPEAK IN A CLASSROOM","The man may not be teaching, and if he is, it might be something other than science."]]
# premise_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
# hypothesis_highlighted_1: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
# premise_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
# hypothesis_highlighted_2: [["","","","","",...,"","","","",""],["","","","","",...,"","","","",""],...,["","","","","",...,"","","","",""],["","","","","",...,"","","","",""]]
# ...

# %%
esnli_test_antonyms.to_csv("../datasets/esnli_antonyms.csv")
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 315616
