# %%
import json

import sys
sys.path.append('..')
from semplotlib import plot_confusion_heatmap

# %% [markdown]
# ## Important words

# %%
path_mapping = {
    "default": "../scripts/metrics_by_phenomena/results/roberta-base-finetuned-mnli.json",
    "hypothesis-only": "../scripts/metrics_by_phenomena/results/roberta-base-finetuned-mnli-hypothesis-only.json",
    "filtered": "../scripts/metrics_by_phenomena/results/roberta-base-finetuned-mnli-maximum_two_6.json"
}

for model in path_mapping.items():
    with open(model[1], "r") as f:
        metrics_data_hypothesis_only = json.load(f)
        for phenomenon_data in metrics_data_hypothesis_only:
            print(f"{model[0]} {phenomenon_data['task_name']}")
            plot_confusion_heatmap(phenomenon_data["confusion_matrix"], relative=True)
# Out:
# default synonym
# default antonym
# default hypernym
# default hyponym
# default co_hyponym
# default quantifiers
# default numericals
# hypothesis-only synonym
# hypothesis-only antonym
# hypothesis-only hypernym
# hypothesis-only hyponym
# hypothesis-only co_hyponym
# hypothesis-only quantifiers
# hypothesis-only numericals
# filtered synonym
# filtered antonym
# filtered hypernym
# filtered hyponym
# filtered co_hyponym
# filtered quantifiers
# filtered numericals

# %% [markdown]
# ## All words

# %%
path_mapping = {
    "default": "../scripts/metrics_by_phenomena_all_words/results/roberta-base-finetuned-mnli.json",
    "hypothesis-only": "../scripts/metrics_by_phenomena_all_words/results/roberta-base-finetuned-mnli-hypothesis-only.json",
    "filtered": "../scripts/metrics_by_phenomena_all_words/results/roberta-base-finetuned-mnli-maximum_two_6.json"
}

for model in path_mapping.items():
    with open(model[1], "r") as f:
        metrics_data_hypothesis_only = json.load(f)
        for phenomenon_data in metrics_data_hypothesis_only:
            print(f"{model[0]} {phenomenon_data['task_name']}")
            plot_confusion_heatmap(phenomenon_data["confusion_matrix"], relative=True)
# Out:
# default synonym
# default antonym
# default hypernym
# default hyponym
# default co_hyponym
# default quantifiers
# default numericals
# hypothesis-only synonym
# hypothesis-only antonym
# hypothesis-only hypernym
# hypothesis-only hyponym
# hypothesis-only co_hyponym
# hypothesis-only quantifiers
# hypothesis-only numericals
# filtered synonym
# filtered antonym
# filtered hypernym
# filtered hyponym
# filtered co_hyponym
# filtered quantifiers
# filtered numericals
